# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# %%
x = np.linspace(0,10, 21)
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,
#         5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. ])

# %%
y = 3*x+4
y
# Out:
# array([ 4. ,  5.5,  7. ,  8.5, 10. , 11.5, 13. , 14.5, 16. , 17.5, 19. ,
#        20.5, 22. , 23.5, 25. , 26.5, 28. , 29.5, 31. , 32.5, 34. ])

# %%
fig = plt.figure()
plt.scatter(x,y)
plt.plot(x,y)

# %%
y1 = np.random.uniform(low=-1, high=1, size=y.shape)*3
y1 = y1 +y
y1
# Out:
# array([ 6.96042773,  3.06658888,  7.8562424 ,  7.33503648,  7.54652728,
#        10.96890468, 15.81880002, 14.71273198, 14.29543047, 14.5666252 ,
#        20.28640642, 23.29017172, 23.34498233, 23.22064741, 24.04093592,
#        28.41913259, 29.96686194, 30.12503024, 32.19026954, 30.13558345,
#        32.54875031])

# %%
plt.scatter(x,y1)

# %%
p, cov = optimize.curve_fit(lambda x, m, l: x*m+l, x, y)
print(p, cov)
# Out:
# [3. 4.] [[ 0. -0.]
#  [-0.  0.]]

# %%
p, cov = optimize.curve_fit(lambda x, m, l: x*m+l, x, y1)
print(p, cov)
# Out:
# [3.0148427  4.00655257] [[ 0.01960398 -0.09801992]
#  [-0.09801992  0.6698028 ]]

# %%
y_fit = x*p[0] + p[1]

plt.figure(1, figsize=(5,5))
plt.scatter(x,y1, color="teal")
plt.plot(x,y_fit, color='orange' )

# %%
y_fit = x*p[0] + p[1]
fig ,ax= plt.subplots( figsize=(5,10))

plt.title("Linear regression", fontsize=25)
plt.scatter(x,y1, color="teal", s=30,label = 'Input values')
plt.plot(x,y_fit, color='orange',linewidth=1, label = 'Curve fit' )
plt.legend(loc = 'upper left')

plt.xlabel('valores x', fontsize=18)
plt.ylabel('valores y', fontsize=18)
ax.set_aspect('equal')
plt.grid(axis='y', color='lightgrey')
plt.grid(axis='x', color='lightgrey')
ax.xlim(35)
ax.ylim(35)
plt.savefig( 'Exemplo_reg_lin' + '.png', format ='png',  bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1784/2550892949.py in <module>
#      12 plt.grid(axis='y', color='lightgrey')
#      13 plt.grid(axis='x', color='lightgrey')
# ---> 14 ax.get_xlim(35)
#      15 ax.get_ylim(35)
#      16 plt.savefig( 'Exemplo_reg_lin' + '.png', format ='png',  bbox_inches='tight')
#
# TypeError: get_xlim() takes 1 positional argument but 2 were given
